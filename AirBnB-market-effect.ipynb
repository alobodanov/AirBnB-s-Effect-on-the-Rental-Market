# %% [markdown]
# AirBnB's Effect on the Rental Market
#
# What happened to MLS listings with the introduction of AirBnB in Toronto?
# Did it affect the number of MLS listings?

# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Read the csv
reviews_df = pd.read_csv("reviews.csv")

# Display data table for preview
reviews_df.head()
# Out:
#    listing_id  month  day  Year
# 0        1419      7   19  2015
# 1        1419      8   29  2015
# 2        1419      9    7  2015
# 3        1419      3   28  2016
# 4        1419      8    3  2017

# %%
reviews_df.shape
# Out:
# (470371, 4)

# %% [markdown]
# Since there is no yearly data of Airbnb listings, we looked at Airbnb reviews as basis rented airbnb listings per year. Some listings have more than 1 review per year (multiple rows). We kept only 1 to represent a rented listing in that particular year.

# %%
# Remove duplicates 
clean_df = reviews_df.drop_duplicates(subset=["listing_id", "Year"])
clean_df.shape
# Out:
# (32722, 4)

# %%
# Use groupby to count the number of rented listing per year
airbnb = clean_df.groupby("Year").count()["listing_id"]
airbnb
# Out:
# Year
# 2009        1
# 2010        9
# 2011       42
# 2012      135
# 2013      357
# 2014      833
# 2015     2249
# 2016     4623
# 2017     7640
# 2018    13234
# 2019     3599
# Name: listing_id, dtype: int64

# %%
# Drop 2019 since this data is incomplete - 2019 is not done yet.
airbnb = airbnb.drop(airbnb.index[10])
airbnb
# Out:
# Year
# 2009        1
# 2010        9
# 2011       42
# 2012      135
# 2013      357
# 2014      833
# 2015     2249
# 2016     4623
# 2017     7640
# 2018    13234
# Name: listing_id, dtype: int64

# %%
# Create bar graph - series method
airbnb_chart = airbnb.plot(kind="bar", title = "Rented Airbnb Listings Per Year\n", color="red")

airbnb_chart.set_xlabel("Year")
airbnb_chart.set_ylabel("Number of Rented Airbnb")

# Save Figure
plt.savefig("Rented_Airbnb_Listings_Per_Year.png")

# %% [markdown]
# The above chart shows that there is an increasing patronage of Airbnb in Toronto every year.
# This will be compared with Toronto MLS data

# %%
# Read the CSV
mls_df = pd.read_csv("MLS_Summary.csv")

# Display data table for preview
mls_df.set_index('Year', inplace=True)
mls_df
# Out:
#      MLS_Listed MLS_Leased
# Year
# 2012     24,397     13,641
# 2013     30,760     16,538
# 2014     35,828     19,562
# 2015     44,980     24,878
# 2016     36,776     24,188
# 2017     35,181     23,659
# 2018     36,373     23,792

# %%
mls_df.dtypes
# Out:
# MLS_Listed    object
# MLS_Leased    object
# dtype: object

# %% [markdown]
# Methods we tried converting string to float that all did not work...
# A) mls_df = pd.read_csv("MLS_Summary.csv", dtype={"MLS_Listed":float})
# B) mls_df['MLS_Listed'] = pd.to_numeric(mls_df['MLS_Listed'])
# C) mls_df.MLS_Listed.astype(dtype=float)

# %%
# Remove , on dataset
mls_df['MLS_Listed']  = mls_df['MLS_Listed'].apply(lambda x: int(x.replace(",", "")))
mls_df['MLS_Leased']  = mls_df['MLS_Leased'].apply(lambda x: int(x.replace(",", "")))

# %%
mls_df.dtypes
# Out:
# MLS_Listed    int64
# MLS_Leased    int64
# dtype: object

# %%
airbnb = pd.DataFrame(airbnb)
airbnb = airbnb.rename(columns={"listing_id": "Airbnb_Leased"})
airbnb
# Out:
#       Airbnb_Leased
# Year
# 2009              1
# 2010              9
# 2011             42
# 2012            135
# 2013            357
# 2014            833
# 2015           2249
# 2016           4623
# 2017           7640
# 2018          13234

# %%
merge_table = pd.merge(mls_df, airbnb, left_index=True, right_index=True)
merge_table
# Out:
#       MLS_Listed  MLS_Leased  Airbnb_Leased
# Year
# 2012       24397       13641            135
# 2013       30760       16538            357
# 2014       35828       19562            833
# 2015       44980       24878           2249
# 2016       36776       24188           4623
# 2017       35181       23659           7640
# 2018       36373       23792          13234

# %%
merge_chart = merge_table.plot(kind="bar")

merge_chart

plt.title("Listing Comparison")

# Save Figure
plt.savefig("Listing_Comparison.png")

# %% [markdown]
# Above chart shows that although the rented airbnb properties increased, it did not affect mls listings at all. MLS listed properties (both leased and not leased) were increasing from 2012 to 2015. It dropped on 2016 and there was little to no movement from 2016 to 2018. MLS listed and MLS leased have the same trend, unaffected by airbnb leased properties.
#
# To further prove that there is no relationship. We used regression model below. Comparing MLS leased vs Airbnb leased, also MLS listed vs Airbnb listed, both resulted in high p-values. There is little or no evidence against the null hypothesis.

# %%
from statsmodels.formula.api import ols

# %%
result = ols(formula="MLS_Leased ~ Airbnb_Leased", data=merge_table).fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             MLS_Leased   R-squared:                       0.394
# Model:                            OLS   Adj. R-squared:                  0.273
# Method:                 Least Squares   F-statistic:                     3.247
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):              0.131
# Time:                        02:50:27   Log-Likelihood:                -66.366
# No. Observations:                   7   AIC:                             136.7
# Df Residuals:                       5   BIC:                             136.6
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      1.852e+04   1935.289      9.570      0.000    1.35e+04    2.35e+04
# Airbnb_Leased     0.5714      0.317      1.802      0.131      -0.244       1.386
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.770
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.310
# Skew:                           0.065   Prob(JB):                        0.857
# Kurtosis:                       1.978   Cond. No.                     8.33e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\artem\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:72: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
#   "samples were given." % int(n), ValueWarning)

# %%
result = ols(formula="MLS_Listed ~ Airbnb_Leased", data=merge_table).fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             MLS_Listed   R-squared:                       0.078
# Model:                            OLS   Adj. R-squared:                 -0.106
# Method:                 Least Squares   F-statistic:                    0.4255
# Date:                Thu, 14 Mar 2019   Prob (F-statistic):              0.543
# Time:                        02:50:30   Log-Likelihood:                -70.309
# No. Observations:                   7   AIC:                             144.6
# Df Residuals:                       5   BIC:                             144.5
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      3.339e+04   3399.367      9.823      0.000    2.47e+04    4.21e+04
# Airbnb_Leased     0.3633      0.557      0.652      0.543      -1.068       1.795
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.051
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.197
# Skew:                           0.411   Prob(JB):                        0.906
# Kurtosis:                       3.005   Cond. No.                     8.33e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.33e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# C:\Users\artem\Anaconda3\lib\site-packages\statsmodels\stats\stattools.py:72: ValueWarning: omni_normtest is not valid with less than 8 observations; 7 samples were given.
#   "samples were given." % int(n), ValueWarning)

# %%
a_data = pd.read_csv("listings.csv")
a_data.head()
# Out:
#       id                                             name  host_id  \
# 0   1419                  Beautiful home in amazing area!     1565
# 1   8077               Downtown Harbourfront Private Room    22795
# 2  12604                   Seaton Village Parlour Bedroom    48239
# 3  23691                  Queen Bedroom close to downtown    93825
# 4  26654  World Class downtown@ CN Tower! Jays, TIFF, ACC   113345
#
#         host_name  neighbourhood_group                      neighbourhood  \
# 0       Alexandra                  NaN                    Little Portugal
# 1  Kathie & Larry                  NaN  Waterfront Communities-The Island
# 2            Rona                  NaN                              Annex
# 3   Yohan & Sarah                  NaN               Briar Hill-Belgravia
# 4           Adela                  NaN  Waterfront Communities-The Island
#
#     latitude  longitude        room_type  price  minimum_nights  \
# 0  43.646168 -79.424510  Entire home/apt    470               4
# 1  43.641051 -79.376277     Private room    100             180
# 2  43.667241 -79.415978     Private room     66               1
# 3  43.696017 -79.454683     Private room     70               1
# 4  43.645305 -79.389404  Entire home/apt    199               5
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  7  2017-12-04               0.16
# 1                169  2013-08-27               1.48
# 2                  0         NaN                NaN
# 3                207  2018-12-30               1.97
# 4                 35  2018-10-23               0.36
#
#    calculated_host_listings_count  availability_365
# 0                               1                 0
# 1                               2                 0
# 2                               1                 0
# 3                               2               351
# 4                               7               328

# %% [markdown]
# Why is there no relationship? Let us explore airbnb data instead.

# %%
a_data = a_data[["id", "neighbourhood", "room_type", "price", "minimum_nights", "number_of_reviews", "availability_365"]]
a_data.head()
# Out:
#       id                      neighbourhood        room_type  price  \
# 0   1419                    Little Portugal  Entire home/apt    470
# 1   8077  Waterfront Communities-The Island     Private room    100
# 2  12604                              Annex     Private room     66
# 3  23691               Briar Hill-Belgravia     Private room     70
# 4  26654  Waterfront Communities-The Island  Entire home/apt    199
#
#    minimum_nights  number_of_reviews  availability_365
# 0               4                  7                 0
# 1             180                169                 0
# 2               1                  0                 0
# 3               1                207               351
# 4               5                 35               328

# %%
# % of Total listings by Room Type
per_room = a_data.groupby(["room_type"]).count()["id"]

# Create lists
room_list = ["Entire home/apt", "Private room", "Shared room" ] 
color_list = ["blue", "red", "yellow" ]

# Build Pie Chart
plt.pie(per_room, labels=room_list, colors=color_list, startangle = 160, explode=(0, 0, 0.1), shadow=True, autopct='%1.1f%%')
plt.title("% of Total Listings by Room Type")

# Save Figure
plt.savefig("Percent_of_Total_Listings_by_Room_Type.png")

# %% [markdown]
# MLS listings cater customers renting entire homes. Whether these clients get a bachelor's pad, 1 bedroom or 2 bedroom, they are renting it for long-term thus they want an entire home. Airbnb however has a different kind of clientele - mostly for short-term stay. Though the graph shows 64% of the listing is entire home, there is still a big chunk of private rooms at 34.2%. Since the two listings cater to different groups, then there is no relationship between them.

# %%
# % of Total Reviews by Room Type
per_review = a_data.groupby(["room_type"]).mean()["number_of_reviews"]

# Build Pie Chart
plt.pie(per_review, labels=room_list, colors=color_list, startangle = 160, explode=(0, 0, 0.1), shadow=True, autopct='%1.1f%%')
plt.title("% of Total Reviews by Room Type")

# Save Figure
plt.savefig("Percent_of_Total_Reviews_by_Room_Type.png")

# %% [markdown]
# To further support the statement above, let us look at the # of reviews. The number of reviews is an indicator of occupancy. Also important to note that this is an under representation since not all airbnb renters leave a review. Although only 1.8% of the inventory is shared rooms but shared rooms have 23% of total reviews. 54.8% of total reviews belong to both private rooms and shared rooms even if the total inventory of both is only 36% of the pie.

# %%
# Create the bins in which Data will be held
bins = [-1, 90, 180, 270, 365]

# Create the names for the four bins
group_names = ["0-90 days", "91-180 days", "181-270 days", "271-365"]

a_data["Availability"] = pd.cut(a_data["availability_365"], bins, labels=group_names)
a_data
# Out:
#              id                        neighbourhood        room_type  price  \
# 0          1419                      Little Portugal  Entire home/apt    470
# 1          8077    Waterfront Communities-The Island     Private room    100
# 2         12604                                Annex     Private room     66
# 3         23691                 Briar Hill-Belgravia     Private room     70
# 4         26654    Waterfront Communities-The Island  Entire home/apt    199
# 5         27423                    Greenwood-Coxwell  Entire home/apt     54
# 6         28160                  Mount Pleasant West  Entire home/apt     66
# 7         30931    Waterfront Communities-The Island  Entire home/apt    133
# 8         40456                       South Parkdale  Entire home/apt    125
# 9         41887                             Oakridge  Entire home/apt     65
# 10        43964                     Wexford/Maryvale  Entire home/apt    110
# 11        44452                  Rosedale-Moore Park  Entire home/apt    100
# 12        44469                  Rosedale-Moore Park     Private room    119
# 13        45399                Church-Yonge Corridor  Entire home/apt    100
# 14        45453                  Rosedale-Moore Park     Private room    100
# 15        45893                  Rosedale-Moore Park     Private room     85
# 16        50110                Church-Yonge Corridor  Entire home/apt    125
# 17        51616                              Niagara     Private room     80
# 18        57483    Waterfront Communities-The Island  Entire home/apt    175
# 19        63395    Waterfront Communities-The Island  Entire home/apt    141
# 20        64003                            Moss Park  Entire home/apt    314
# 21        65238              Palmerston-Little Italy     Private room     56
# 22        69464                  Rosedale-Moore Park  Entire home/apt    125
# 23        71118                              Niagara     Private room     96
# 24        75051                       Dufferin Grove  Entire home/apt    145
# 25        84076                              Niagara  Entire home/apt    145
# 26        84151                Church-Yonge Corridor  Entire home/apt    145
# 27        89575                 Briar Hill-Belgravia     Private room     60
# 28        96336                              Niagara  Entire home/apt    219
# 29        98136    Waterfront Communities-The Island  Entire home/apt    300
# ...         ...                                  ...              ...    ...
# 19623  31488174                     Newtonbrook East  Entire home/apt    111
# 19624  31489732              York University Heights  Entire home/apt    100
# 19625  31490076                      Flemingdon Park  Entire home/apt     60
# 19626  31490946    Waterfront Communities-The Island  Entire home/apt    230
# 19627  31491202                                Rouge     Private room    168
# 19628  31492459  Dovercourt-Wallace Emerson-Junction  Entire home/apt    100
# 19629  31494301                           Maple Leaf     Private room     36
# 19630  31494734    Waterfront Communities-The Island  Entire home/apt    230
# 19631  31494976                  Bay Street Corridor  Entire home/apt    125
# 19632  31495001    Waterfront Communities-The Island     Private room     49
# 19633  31495158                              Niagara      Shared room    200
# 19634  31495540                                Rouge     Private room     76
# 19635  31496554                Church-Yonge Corridor  Entire home/apt     90
# 19636  31497747                  Rosedale-Moore Park  Entire home/apt    170
# 19637  31497943                                Annex  Entire home/apt    170
# 19638  31498493                      Willowdale East     Private room     80
# 19639  31507950                      South Riverdale  Entire home/apt    100
# 19640  31509247                  North St.James Town     Private room     46
# 19641  31509275                     Newtonbrook West     Private room     50
# 19642  31512898                         Roncesvalles     Private room     45
# 19643  31513376                            Casa Loma     Private room     58
# 19644  31516104                       Dufferin Grove  Entire home/apt     60
# 19645  31516298                           University     Private room     80
# 19646  31516623                Church-Yonge Corridor     Private room     36
# 19647  31516990                    Woodbine Corridor     Private room    100
# 19648  31517024                  Clairlea-Birchmount  Entire home/apt     61
# 19649  31517341                      Willowdale West     Private room     50
# 19650  31517380                    Woodbine Corridor     Private room    150
# 19651  31518185                      North Riverdale  Entire home/apt    115
# 19652  31518232                              Niagara  Entire home/apt     96
#
#        minimum_nights  number_of_reviews  availability_365  Availability
# 0                   4                  7                 0     0-90 days
# 1                 180                169                 0     0-90 days
# 2                   1                  0                 0     0-90 days
# 3                   1                207               351       271-365
# 4                   5                 35               328       271-365
# 5                 120                 26                 0     0-90 days
# 6                  28                  7               309       271-365
# 7                 180                  1               365       271-365
# 8                  28                 98                 0     0-90 days
# 9                   2                 78                40     0-90 days
# 10                  2                 25               343       271-365
# 11                  1                 44               342       271-365
# 12                  1                  8               287       271-365
# 13                  1                 63               261  181-270 days
# 14                  1                  9               365       271-365
# 15                  1                 17                 0     0-90 days
# 16                  1                 39               279       271-365
# 17                  1                 24                90     0-90 days
# 18                 29                  0                92   91-180 days
# 19                 60                  1               184  181-270 days
# 20                  3                 75               197  181-270 days
# 21                  3                 52               161   91-180 days
# 22                  1                 37               346       271-365
# 23                  6                 11               346       271-365
# 24                  5                272               226  181-270 days
# 25                  3                  6                 0     0-90 days
# 26                  1                 24               340       271-365
# 27                  1                 82               322       271-365
# 28                  3                104               220  181-270 days
# 29                  2                 55                84     0-90 days
# ...               ...                ...               ...           ...
# 19623               3                  0                64     0-90 days
# 19624              15                  0                71     0-90 days
# 19625               1                  0               133   91-180 days
# 19626               7                  0                90     0-90 days
# 19627               2                  0               365       271-365
# 19628               1                  0               110   91-180 days
# 19629               5                  0               365       271-365
# 19630               1                  0               180   91-180 days
# 19631              30                  0               106   91-180 days
# 19632               8                  0                17     0-90 days
# 19633               1                  0               364       271-365
# 19634               1                  0                65     0-90 days
# 19635               2                  0               144   91-180 days
# 19636              90                  0               223  181-270 days
# 19637               1                  0                84     0-90 days
# 19638               5                  0                51     0-90 days
# 19639               7                  0               359       271-365
# 19640               3                  0                16     0-90 days
# 19641               1                  0               344       271-365
# 19642               2                  0                18     0-90 days
# 19643               3                  0                16     0-90 days
# 19644               2                  0                51     0-90 days
# 19645               1                  0                71     0-90 days
# 19646               1                  0               176   91-180 days
# 19647               1                  0                78     0-90 days
# 19648               3                  0               263  181-270 days
# 19649               1                  0               346       271-365
# 19650               1                  0                83     0-90 days
# 19651               5                  0                 8     0-90 days
# 19652               1                  0               352       271-365
#
# [19653 rows x 8 columns]

# %%
# % of Availability
per_availability = a_data.groupby(["Availability"]).count()["id"]

# Build Pie Chart
plt.pie(per_availability, labels=group_names, startangle = 160, explode=(0, 0, 0, 0.1), shadow=True, autopct='%1.1f%%')
plt.title("% of Availability")

# Save Figure
plt.savefig("Percent_of_Availability.png")

# %% [markdown]
# MLS listings are available all year round since it is intended for long term rental. The reason why Airbnb is not affecting MLS listings is because only 21.8% of Airbnb listings are available for 271 to 365 days. Majority of Airbnb listings are available for 1-90 days only. Airbnb listing is not always available probably because Airbnb property owners are also using that property. In conclusion, Airbnb and MLS listings are different types of rental and are serving different clients, thus, one is not affecting the other.

# %%
#MLS DATA

# %%
csv_path = "MLS Rental Market Report.csv"
Rental_Market_Report_df = pd.read_csv(csv_path)
Rental_Market_Report_df
# Out:
#     Year District  Listed  Rented  Bachelor Bachelor Avg Monthly   1-Bed  \
# 0   2006      C01    3938    2153       111             $1,172.00   1421
# 1   2007      C01    4137    2396       120             $1,191.33   1546
# 2   2008      C01    4819    2856       176             $1,217.00   1854
# 3   2009      C01    6293    3622       222             $1,213.33   2239
# 4   2010      C01    8068    4738       237             $1,226.67   2979
# 5   2011      C01   10360    6644       363             $1,310.67   4170
# 6   2012      C01    8370    4964       224             $1,379.50   3060
# 7   2013      C01   12880    6812       316             $1,375.00   4302
# 8   2014      C01   15020    8268       367             $1,383.00   5332
# 9   2015      C01   18086   10199       561             $1,376.25   6482
# 10  2016      C01   16124   10622       657             $1,477.25   6690
# 11  2017      C01   14318    9513       573             $1,636.75   5879
# 12  2018      C01   13725    8894       561             $1,818.50   5629
#
#     1-Bed Avg Monthly   2-Bed  2-Bed Avg Monthly   3-Bed 3-Bed Avg Monthly
# 0            $1,491.00    605           $2,201.00     16          $4,029.67
# 1            $1,527.67    711           $2,246.67     19          $4,512.00
# 2            $1,584.00    813           $2,305.67     13          $3,486.67
# 3            $1,542.33   1138           $2,210.33     23          $3,416.67
# 4            $1,567.00   1485           $2,255.67     37          $3,757.33
# 5            $1,695.33   2026           $2,546.33     85          $3,789.33
# 6            $1,762.75   1618           $2,607.50     62          $3,780.75
# 7            $1,759.75   2117           $2,609.00     77          $4,054.75
# 8            $1,760.75   2463           $2,580.50    106          $3,962.75
# 9            $1,756.75   2961           $2,622.25    195          $3,464.00
# 10           $1,867.75   3076           $2,850.50    199          $3,968.25
# 11           $2,071.75   2861           $3,017.50    200          $4,291.25
# 12           $2,283.25   2536           $3,276.00    168          $4,417.75

# %%
plt.figure(figsize=(12,5))
plt.bar(Rental_Market_Report_df["Year"], Rental_Market_Report_df["Rented"], color='r')
plt.xticks(Rental_Market_Report_df["Year"])
# plt.bar(Rental_Market_Report_df["Year"], Rental_Market_Report_df["Listed"], color='b')
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.bar(Rental_Market_Report_df["Year"], Rental_Market_Report_df["Bachelor"], color='b')
plt.xticks(Rental_Market_Report_df["Year"])
plt.title("title")
plt.show()

# Save Figure
plt.savefig("bachelor.png")

# %%
plt.figure(figsize=(12,5))
plt.bar(Rental_Market_Report_df["Year"], Rental_Market_Report_df["1-Bed"], color='b')
plt.xticks(Rental_Market_Report_df["Year"])
plt.title("title")
plt.show()

# Save Figure
plt.savefig("one-bedroom.png")

# %%
plt.figure(figsize=(12,5))
plt.bar(Rental_Market_Report_df["Year"], Rental_Market_Report_df["2-Bed"], color='b')
plt.xticks(Rental_Market_Report_df["Year"])
plt.title("title")
plt.show()

# Save Figure
plt.savefig("two-bedroom.png")

# %%
plt.figure(figsize=(12,5))
plt.bar(Rental_Market_Report_df["Year"], Rental_Market_Report_df["3-Bed"], color='b')
plt.xticks(Rental_Market_Report_df["Year"])
plt.title("title")
plt.show()

# Save Figure
plt.savefig("three-bedroom.png")
